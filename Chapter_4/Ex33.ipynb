# %%
import stanza
from collections import Counter

# Initialize the StanfordNLP pipeline
with open('../Data/Alice/Alice.txt') as textFile:
    content = textFile.read()


# Process the text
nlp = stanza.Pipeline('en', processors='pos,tokenize,lemma')
doc = nlp(content)

for sentence in doc.sentences:
    for word in sentence.words:
        # print(word)
        if word.text == 'of':
            prevId = word.id - 1
            afterId = word.id + 1
            prevWord = next(
                (word for word in sentence.words if word.id == prevId), None)
            afterWord = next(
                (word for word in sentence.words if word.id == afterId), None)
            if (prevWord.upos == 'NOUN' and afterWord.upos == "NOUN"):
                print(f"{prevWord.text} of {afterWord.text}")
# Out:
# 2023-11-01 21:53:02 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# ...
# 2023-11-01 21:53:04 INFO: Loading these models for language: en (English):
# ...
# | Processor | Package           |
# ---------------------------------
# | tokenize  | combined          |
# | pos       | combined_charlm   |
# | lemma     | combined_nocharlm |
# ...
#
# 2023-11-01 21:53:04 INFO: Using device: cpu
# 2023-11-01 21:53:04 INFO: Loading: tokenize
# 2023-11-01 21:53:04 INFO: Loading: pos
# 2023-11-01 21:53:05 INFO: Loading: lemma
# 2023-11-01 21:53:05 INFO: Done loading processors!
# plenty of time
# saucer of milk
# sort of way
# heap of sticks
# row of lamps
# book of rules
# flavour of cherry
# game of croquet
# pair of boots
# gallons of tears
# pattering of feet
# sorts of things
# burst of tears
# number of bathing
# row of lodging
# pool of tears
# ...
