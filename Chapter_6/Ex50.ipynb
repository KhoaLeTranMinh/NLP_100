# %%
import os
import random
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sympy import false


def seed_everything(seed=42):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    
seed_everything(seed=42)

save_dir = "../Data/Output/Chapter6/"

columns = ['id', 'title', 'url', 'publisher',
           'category', 'story', 'hostname', 'timestamp']
df = pd.read_csv("../Data/Chapter6/newsCorpora.csv",
                 sep='\t', names=columns, index_col='id')
required_df = df[df['publisher'].isin(
    ['Reuters', 'Huffington Post', 'Businessweek', 'Contactmusic.com', 'Daily Mail'])]

print(required_df)
df_train, df_val_test = train_test_split( required_df, test_size=0.2, shuffle=True)
df_val, df_test = train_test_split(df_val_test, test_size=0.5, shuffle=True)

df_train.to_csv(os.path.join(save_dir, 'ex50-train.txt'), sep='\t')
df_val.to_csv(os.path.join(save_dir, 'ex50-valid.txt'), sep='\t')
df_test.to_csv(os.path.join(save_dir, 'ex50-test.txt'), sep='\t')


print('df_train record size:', len(df_train))
print('df_val record size:', len(df_val))
print('df_test record size:', len(df_test))
# Out:
#                                                     title
# id
# 13           Europe reaches crunch point on banking union  \
# 14      ECB FOCUS-Stronger euro drowns out ECB's messa...
# 20      Euro Anxieties Wane as Bunds Top Treasuries, S...
# 21      Noyer Says Strong Euro Creates Unwarranted Eco...
# 30      REFILE-Bad loan triggers key feature in ECB ba...
# ...                                                   ...
# 422819     UN: Ebola Could Eventually Infect 20000 People
# 422820  Ebola toll tops 1550, continues to accelerate ...
# 422821  UPDATE 1-Ebola toll tops 1550, outbreak accele...
# 422828  Ebola Cases May Surpass 20000, WHO Says in Upd...
# 422838  Air France suspends flights to Ebola-hit Sierr...
#
#                                                       url        publisher
# id
# 13      http://in.reuters.com/article/2014/03/10/eu-ba...          Reuters  \
# 14      http://in.reuters.com/article/2014/03/10/ecb-p...          Reuters
# ...
